# %%
#importing libraries
import pandas as pd  
import numpy as np

df = pd.read_excel("World_development_mesurement (1) (1).xlsx") #Loading the dataset
df.head(10)
# Out:
#    Birth Rate Business Tax Rate  CO2 Emissions                   Country  \
# 0       0.020               NaN        87931.0                   Algeria
# 1       0.050               NaN         9542.0                    Angola
# 2       0.043               NaN         1617.0                     Benin
# 3       0.027               NaN         4276.0                  Botswana
# 4       0.046               NaN         1041.0              Burkina Faso
# 5       0.042               NaN          301.0                   Burundi
# 6       0.041               NaN         3432.0                  Cameroon
# 7       0.039               NaN          268.0  Central African Republic
# 8       0.051               NaN          176.0                      Chad
# 9       0.039               NaN           84.0                   Comoros
#
#    Days to Start Business  Ease of Business  Energy Usage              GDP  \
# 0                     NaN               NaN       26998.0  $54,790,058,957
# 1                     NaN               NaN        7499.0   $9,129,594,819
# 2                     NaN               NaN        1983.0   $2,359,122,303
# 3                     NaN               NaN        1836.0   $5,788,311,645
# 4                     NaN               NaN           NaN   $2,610,959,139
# 5                     NaN               NaN           NaN     $870,486,066
# 6                     NaN               NaN        6310.0   $9,287,367,569
# 7                     NaN               NaN           NaN     $914,500,332
# 8                     NaN               NaN           NaN   $1,385,058,212
# 9                     NaN               NaN           NaN     $201,899,884
#
#    Health Exp % GDP Health Exp/Capita  ...  Life Expectancy Male  \
# 0             0.035               $60  ...                  67.0
# 1             0.034               $22  ...                  44.0
# 2             0.043               $15  ...                  53.0
# 3             0.047              $152  ...                  49.0
# 4             0.051               $12  ...                  49.0
# 5             0.063                $7  ...                  47.0
# 6             0.044               $26  ...                  51.0
# 7             0.043               $11  ...                  42.0
# 8             0.063               $10  ...                  46.0
# 9             0.035               $13  ...                  56.0
#
#    Mobile Phone Usage  Number of Records  Population 0-14  Population 15-64  \
# 0                 0.0                  1            0.342             0.619
# 1                 0.0                  1            0.476             0.499
# 2                 0.0                  1            0.454             0.517
# 3                 0.1                  1            0.383             0.587
# 4                 0.0                  1            0.468             0.505
# 5                 0.0                  1            0.490             0.481
# 6                 0.0                  1            0.453             0.513
# 7                 0.0                  1            0.423             0.537
# 8                 0.0                  1            0.490             0.482
# 9                 NaN                  1            0.415             0.554
#
#    Population 65+  Population Total  Population Urban  Tourism Inbound  \
# 0           0.039          31719449             0.599     $102,000,000
# 1           0.025          13924930             0.324      $34,000,000
# 2           0.029           6949366             0.383      $77,000,000
# 3           0.029           1755375             0.532     $227,000,000
# 4           0.028          11607944             0.178      $23,000,000
# 5           0.029           6674286             0.082       $1,400,000
# 6           0.034          15927713             0.455     $132,000,000
# 7           0.040           3638316             0.376       $5,000,000
# 8           0.028           8301151             0.216      $14,000,000
# 9           0.031            528312             0.281      $15,000,000
#
#    Tourism Outbound
# 0      $193,000,000
# 1      $146,000,000
# 2       $50,000,000
# 3      $209,000,000
# 4       $30,000,000
# 5       $14,000,000
# 6      $241,000,000
# 7       $33,000,000
# 8       $56,000,000
# 9               NaN
#
# [10 rows x 25 columns]

# %%
df.info() #Info about the dataset
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Birth Rate              2585 non-null   float64
#  1   Business Tax Rate       1423 non-null   str
#  2   CO2 Emissions           2125 non-null   float64
#  3   Country                 2704 non-null   str
#  4   Days to Start Business  1718 non-null   float64
#  5   Ease of Business        185 non-null    float64
#  6   Energy Usage            1785 non-null   float64
#  7   GDP                     2494 non-null   str
#  8   Health Exp % GDP        2395 non-null   float64
#  9   Health Exp/Capita       2395 non-null   str
#  10  Hours to do Tax         1416 non-null   float64
#  11  Infant Mortality Rate   2444 non-null   float64
#  12  Internet Usage          2531 non-null   float64
#  13  Lending Interest        1880 non-null   float64
#  14  Life Expectancy Female  2568 non-null   float64
#  15  Life Expectancy Male    2568 non-null   float64
#  16  Mobile Phone Usage      2537 non-null   float64
#  17  Number of Records       2704 non-null   int64
#  18  Population 0-14         2484 non-null   float64
#  19  Population 15-64        2484 non-null   float64
#  20  Population 65+          2484 non-null   float64
#  21  Population Total        2704 non-null   int64
#  22  Population Urban        2678 non-null   float64
#  23  Tourism Inbound         2336 non-null   str
#  24  Tourism Outbound        2233 non-null   str
# dtypes: float64(17), int64(2), str(6)
# memory usage: 528.3 KB

# %%
df.duplicated().sum() #Checking for duplicates in the dataset
# Out:
# np.int64(0)

# %%
df.isnull().sum() #Checking for null values in the dataset
# Out:
# Birth Rate                 119
# Business Tax Rate         1281
# CO2 Emissions              579
# Country                      0
# Days to Start Business     986
# Ease of Business          2519
# Energy Usage               919
# GDP                        210
# Health Exp % GDP           309
# Health Exp/Capita          309
# Hours to do Tax           1288
# Infant Mortality Rate      260
# Internet Usage             173
# Lending Interest           824
# Life Expectancy Female     136
# Life Expectancy Male       136
# Mobile Phone Usage         167
# Number of Records            0
# Population 0-14            220
# Population 15-64           220
# Population 65+             220
# Population Total             0
# Population Urban            26
# Tourism Inbound            368
# Tourism Outbound           471
# dtype: int64

# %%
df1 = df.drop(['Business Tax Rate','Ease of Business','Hours to do Tax','Number of Records','Country'], axis = 1, errors='ignore') #Dropping unnecessary columns from the dataset

# %%
df1.sample(5)
# Out:
#       Birth Rate  CO2 Emissions  Days to Start Business  Energy Usage  \
# 1686       0.039          227.0                   259.0           NaN
# 2306       0.032            NaN                    57.0        1997.0
# 929        0.012        50597.0                     7.0       19428.0
# 1675       0.039         1474.0                   161.0        1260.0
# 2139       0.026         4180.0                   102.0        5024.0
#
#                    GDP  Health Exp % GDP Health Exp/Capita  \
# 1686      $842,890,956             0.060               $34
# 2306   $18,796,191,833             0.034              $401
# 929   $244,727,978,021             0.097            $4,387
# 1675   $11,859,015,181             0.021               $64
# 2139   $11,242,266,334             0.058               $46
#
#       Infant Mortality Rate  Internet Usage  Lending Interest  \
# 1686                  0.089             0.0               NaN
# 2306                  0.042             0.1               NaN
# 929                   0.004             0.8               NaN
# 1675                  0.049             0.0               NaN
# 2139                  0.037             0.0               NaN
#
#       Life Expectancy Female  Life Expectancy Male  Mobile Phone Usage  \
# 1686                    55.0                  52.0                 0.3
# 2306                    64.0                  62.0                 1.5
# 929                     80.0                  75.0                 1.0
# 1675                    57.0                  55.0                 0.5
# 2139                    73.0                  68.0                 0.6
#
#       Population 0-14  Population 15-64  Population 65+  Population Total  \
# 1686            0.423             0.548           0.029           1516920
# 2306            0.385             0.562           0.053           1594034
# 929             0.188             0.662           0.150           5404523
# 1675            0.422             0.544           0.034           3876475
# 2139            0.318             0.631           0.050          14364931
#
#       Population Urban Tourism Inbound Tourism Outbound
# 1686             0.435     $38,200,000      $46,100,000
# 2306             0.860             NaN              NaN
# 929              0.856  $5,652,000,000   $7,279,000,000
# 1675             0.623             NaN              NaN
# 2139             0.198  $1,332,000,000     $268,000,000

# %%
for col in df1.columns:
    if col != 'Country':
        df1[col] = pd.to_numeric(                   #Convert column to numeric type
            df1[col].astype(str)                    #Convert entire column to string type
            .str.replace('$', '', regex=False)      #Remove '$' from values
            .str.replace(',', '', regex=False),     #Remove ',' from values
            errors='coerce'                         #Convert to numeric, setting non-convertible values to NaN
        )

# %%
df1.sample(10)
# Out:
#       Birth Rate  CO2 Emissions  Days to Start Business  Energy Usage  \
# 1023       0.026         4426.0                    39.0        2821.0
# 1998       0.010        46127.0                    13.0       15177.0
# 2014       0.022        40264.0                    12.0       18279.0
# 1912       0.018          755.0                    39.0           NaN
# 2376         NaN            NaN                     NaN           NaN
# 371        0.020          345.0                     NaN           NaN
# 2464       0.016            NaN                    60.0        4655.0
# 812        0.030         6769.0                    62.0        3647.0
# 14         0.025       141326.0                     NaN       40658.0
# 1156       0.012         4895.0                    30.0        3500.0
#
#                GDP  Health Exp % GDP  Health Exp/Capita  \
# 1023  5.795568e+09             0.061               66.0
# 1998  4.024947e+10             0.105              577.0
# 2014  4.824291e+10             0.030              511.0
# 1912  8.474249e+08             0.027              250.0
# 2376           NaN             0.072             3053.0
# 371   7.783116e+08             0.044              429.0
# 2464  4.123730e+10             0.102              883.0
# 812   8.140294e+09             0.083              103.0
# 14    9.983854e+10             0.054               79.0
# 1156  2.988172e+09             0.092               76.0
#
#       Infant Mortality Rate  Internet Usage  Lending Interest  \
# 1023                  0.027             0.0             0.135
# 1998                  0.007             0.4             0.118
# 2014                  0.010             0.3             0.074
# 1912                  0.012             NaN             0.153
# 2376                  0.002             0.8               NaN
# 371                   0.013             0.1             0.116
# 2464                  0.009             0.4             0.161
# 812                   0.028             0.0             0.208
# 14                    0.036             0.0             0.132
# 1156                  0.019             0.1             0.193
#
#       Life Expectancy Female  Life Expectancy Male  Mobile Phone Usage  \
# 1023                    75.0                  69.0                 0.1
# 1998                    76.0                  71.0                 1.2
# 2014                    78.0                  74.0                 1.5
# 1912                    78.0                  68.0                 1.2
# 2376                     NaN                   NaN                 0.8
# 371                     76.0                  71.0                 0.3
# 2464                    82.0                  77.0                 0.9
# 812                     74.0                  69.0                 0.1
# 14                      71.0                  66.0                 0.0
# 1156                    72.0                  64.0                 0.3
#
#       Population 0-14  Population 15-64  Population 65+  Population Total  \
# 1023            0.384             0.575           0.040           5386299
# 1998            0.171             0.692           0.137           7320807
# 2014            0.292             0.683           0.024           2663224
# 1912            0.225             0.699           0.076             87298
# 2376              NaN               NaN             NaN             77865
# 371             0.291             0.639           0.070             78972
# 2464            0.244             0.689           0.067           4737680
# 812             0.409             0.550           0.041           6628171
# 14              0.354             0.592           0.053          66136590
# 1156            0.190             0.698           0.112           3595187
#
#       Population Urban  Tourism Inbound  Tourism Outbound
# 1023             0.557     1.920000e+08      1.540000e+08
# 1998             0.552     9.890000e+08      1.107000e+09
# 2014             0.746     1.092000e+09      1.295000e+09
# 1912             0.520     2.700000e+07      5.000000e+06
# 2376             0.873              NaN               NaN
# 371              0.317     2.720000e+08      3.200000e+07
# 2464             0.729     2.375000e+09      5.220000e+08
# 812              0.472     3.720000e+08      2.740000e+08
# 14               0.428     4.657000e+09      1.206000e+09
# 1156             0.453     1.380000e+08      1.700000e+08

# %%
df1.dtypes #Checking the data types
# Out:
# Birth Rate                float64
# CO2 Emissions             float64
# Days to Start Business    float64
# Energy Usage              float64
# GDP                       float64
# Health Exp % GDP          float64
# Health Exp/Capita         float64
# Infant Mortality Rate     float64
# Internet Usage            float64
# Lending Interest          float64
# Life Expectancy Female    float64
# Life Expectancy Male      float64
# Mobile Phone Usage        float64
# Population 0-14           float64
# Population 15-64          float64
# Population 65+            float64
# Population Total            int64
# Population Urban          float64
# Tourism Inbound           float64
# Tourism Outbound          float64
# dtype: object

# %%
df1.isnull().sum() #checking for null values
# Out:
# Birth Rate                119
# CO2 Emissions             579
# Days to Start Business    986
# Energy Usage              919
# GDP                       210
# Health Exp % GDP          309
# Health Exp/Capita         309
# Infant Mortality Rate     260
# Internet Usage            173
# Lending Interest          824
# Life Expectancy Female    136
# Life Expectancy Male      136
# Mobile Phone Usage        167
# Population 0-14           220
# Population 15-64          220
# Population 65+            220
# Population Total            0
# Population Urban           26
# Tourism Inbound           368
# Tourism Outbound          471
# dtype: int64

# %%
df1 = df1.fillna(df1.median(numeric_only=True)) # Fill Null values With Median

# %%
df1.isnull().sum() #Checking for null values after filling them with median
# Out:
# Birth Rate                0
# CO2 Emissions             0
# Days to Start Business    0
# Energy Usage              0
# GDP                       0
# Health Exp % GDP          0
# Health Exp/Capita         0
# Infant Mortality Rate     0
# Internet Usage            0
# Lending Interest          0
# Life Expectancy Female    0
# Life Expectancy Male      0
# Mobile Phone Usage        0
# Population 0-14           0
# Population 15-64          0
# Population 65+            0
# Population Total          0
# Population Urban          0
# Tourism Inbound           0
# Tourism Outbound          0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_cols = df1.select_dtypes(include=[np.number]).columns.tolist() #Find Numerical Columns 

plt.figure(figsize=(15, 15))
for i, col in enumerate(num_cols, 1):
    plt.subplot(5, 4, i)
    sns.boxplot(x=df[col], color="skyblue")  #Plot Boxplot For Outlier Detection 
    plt.title(f"Boxplot: {col}")
plt.tight_layout()
plt.show()

# %%
df2 = df1.copy()

for col in num_cols :
    Q1 = df2[col].quantile(0.25)
    Q3 = df2[col].quantile(0.75)
    IQR = Q3 - Q1 

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df2[(df2[col] < lower_bound) | (df2[col] > upper_bound)] #Identify Outliers Based on IQR Method
    print(f'{len(outliers)} Outliers in {col}')
# Out:
# 0 Outliers in Birth Rate
# 387 Outliers in CO2 Emissions
# 340 Outliers in Days to Start Business
# 424 Outliers in Energy Usage
# 414 Outliers in GDP
# 58 Outliers in Health Exp % GDP
# 412 Outliers in Health Exp/Capita
# 49 Outliers in Infant Mortality Rate
# 0 Outliers in Internet Usage
# 245 Outliers in Lending Interest
# 14 Outliers in Life Expectancy Female
# 11 Outliers in Life Expectancy Male
# 11 Outliers in Mobile Phone Usage
# 0 Outliers in Population 0-14
# 9 Outliers in Population 15-64
# 5 Outliers in Population 65+
# 318 Outliers in Population Total
# 0 Outliers in Population Urban
# 409 Outliers in Tourism Inbound
# 461 Outliers in Tourism Outbound

# %%
for col in num_cols :
    Q1 = df2[col].quantile(0.25)
    Q3 = df2[col].quantile(0.75)
    IQR = Q3 - Q1 

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df2[col] = df2[col].apply(lambda x: max(min(x, upper_bound), lower_bound)) # capping For handel Outliers

# %%
plt.figure(figsize = (20,5))
sns.boxplot(df2) #Boxplot after handel outliers with capping method
plt.show()

# %%
for col in num_cols :
    Q1 = df2[col].quantile(0.25)
    Q3 = df2[col].quantile(0.75)
    IQR = Q3 - Q1 

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df2[(df2[col] < lower_bound) | (df2[col] > upper_bound)] #Identify Outliers Based on IQR Method After Capping
    print(f'{len(outliers)} Outliers in {col}')
# Out:
# 0 Outliers in Birth Rate
# 0 Outliers in CO2 Emissions
# 0 Outliers in Days to Start Business
# 0 Outliers in Energy Usage
# 0 Outliers in GDP
# 0 Outliers in Health Exp % GDP
# 0 Outliers in Health Exp/Capita
# 0 Outliers in Infant Mortality Rate
# 0 Outliers in Internet Usage
# 0 Outliers in Lending Interest
# 0 Outliers in Life Expectancy Female
# 0 Outliers in Life Expectancy Male
# 0 Outliers in Mobile Phone Usage
# 0 Outliers in Population 0-14
# 0 Outliers in Population 15-64
# 0 Outliers in Population 65+
# 0 Outliers in Population Total
# 0 Outliers in Population Urban
# 0 Outliers in Tourism Inbound
# 0 Outliers in Tourism Outbound

# %%
df2.describe().T #Statistical Summary of the dataset
# Out:
#                          count          mean           std           min  \
# Birth Rate              2704.0  2.259541e-02  1.110001e-02  7.000000e-03
# CO2 Emissions           2704.0  2.730082e+04  3.653684e+04  7.000000e+00
# Days to Start Business  2704.0  2.813998e+01  1.416760e+01  1.000000e+00
# Energy Usage            2704.0  1.826808e+04  1.477494e+04  8.000000e+00
# GDP                     2704.0  5.968253e+10  8.148197e+10  6.310127e+07
# Health Exp % GDP        2704.0  6.302996e-02  2.213957e-02  8.000000e-03
# Health Exp/Capita       2704.0  3.932594e+02  4.465392e+02  2.000000e+00
# Infant Mortality Rate   2704.0  3.140440e-02  2.821458e-02  2.000000e-03
# Internet Usage          2704.0  2.308062e-01  2.539833e-01  0.000000e+00
# Lending Interest        2704.0  1.258656e-01  4.868189e-02  2.050000e-02
# Life Expectancy Female  2704.0  7.136354e+01  1.043851e+01  4.400000e+01
# Life Expectancy Male    2704.0  6.659911e+01  9.141010e+00  4.300000e+01
# Mobile Phone Usage      2704.0  5.723188e-01  4.566059e-01  0.000000e+00
# Population 0-14         2704.0  3.027622e-01  1.021522e-01  1.180000e-01
# Population 15-64        2704.0  6.249689e-01  6.677060e-02  4.740000e-01
# Population 65+          2704.0  7.168399e-02  4.773518e-02  3.000000e-03
# Population Total        2704.0  1.357105e+07  1.664077e+07  1.887600e+04
# Population Urban        2704.0  5.629242e-01  2.447118e-01  8.200000e-02
# Tourism Inbound         2704.0  1.825707e+09  2.285833e+09  7.000000e+05
# Tourism Outbound        2704.0  1.191360e+09  1.488580e+09  2.000000e+05
#
#                                  25%           50%           75%           max
# Birth Rate              1.300000e-02  2.000000e-02  3.000000e-02  5.300000e-02
# CO2 Emissions           2.237000e+03  8.529000e+03  4.256200e+04  1.030495e+05
# Days to Start Business  2.000000e+01  2.600000e+01  3.425000e+01  5.562500e+01
# Energy Usage            7.851750e+03  1.433800e+04  2.347650e+04  4.691362e+04
# GDP                     4.113748e+09  1.507975e+10  9.101825e+10  2.213750e+11
# Health Exp % GDP        4.800000e-02  6.100000e-02  7.600000e-02  1.180000e-01
# Health Exp/Capita       5.800000e+01  1.930000e+02  5.512500e+02  1.291125e+03
# Infant Mortality Rate   1.000000e-02  2.000000e-02  4.900000e-02  1.075000e-01
# Internet Usage          0.000000e+00  1.000000e-01  4.000000e-01  1.000000e+00
# Lending Interest        9.775000e-02  1.200000e-01  1.492500e-01  2.265000e-01
# Life Expectancy Female  6.500000e+01  7.500000e+01  7.900000e+01  8.700000e+01
# Life Expectancy Male    6.100000e+01  6.900000e+01  7.300000e+01  8.800000e+01
# Mobile Phone Usage      2.000000e-01  5.000000e-01  9.000000e-01  1.950000e+00
# Population 0-14         2.100000e-01  2.995000e-01  3.950000e-01  5.000000e-01
# Population 15-64        5.650000e-01  6.425000e-01  6.730000e-01  8.350000e-01
# Population 65+          3.400000e-02  5.200000e-02  1.050000e-01  2.115000e-01
# Population Total        8.783360e+05  5.800324e+06  2.014089e+07  4.903473e+07
# Population Urban        3.577500e-01  5.600000e-01  7.630000e-01  1.000000e+00
# Tourism Inbound         1.860000e+08  6.885000e+08  2.648000e+09  6.341000e+09
# Tourism Outbound        1.470000e+08  4.560000e+08  1.711500e+09  4.058250e+09

# %%
plt.figure(figsize=(15,15))
for i, col in enumerate(num_cols, 1):
    plt.subplot(6,4, i)
    sns.histplot(df1[col], kde=True, bins=30) #Plot Histplot Of Each Numerical Columns TO identify Features Distributions
    plt.title(f"Histogram: {col}")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.heatmap(df2.corr(numeric_only = True)>0.7, annot = True, cmap = 'coolwarm') #Plot Heatmap To Identify Correlation Between Features
# Out:
# <Axes: >

# %%
df2.corr(numeric_only = True) #Calculate Correlation Matrix To Identify Correlation Between Features
# Out:
#                         Birth Rate  CO2 Emissions  Days to Start Business  \
# Birth Rate                1.000000      -0.351731                0.263394
# CO2 Emissions            -0.351731       1.000000               -0.072469
# Days to Start Business    0.263394      -0.072469                1.000000
# Energy Usage             -0.283022       0.834030               -0.154774
# GDP                      -0.414817       0.731496               -0.207639
# Health Exp % GDP         -0.238268       0.056862               -0.225340
# Health Exp/Capita        -0.586558       0.319254               -0.305008
# Infant Mortality Rate     0.870159      -0.299015                0.260893
# Internet Usage           -0.624617       0.188934               -0.388139
# Lending Interest          0.423805      -0.246069                0.209823
# Life Expectancy Female   -0.865210       0.312254               -0.301963
# Life Expectancy Male     -0.822416       0.295870               -0.312340
# Mobile Phone Usage       -0.538916       0.142886               -0.317268
# Population 0-14           0.941822      -0.396798                0.309020
# Population 15-64         -0.908345       0.366395               -0.265334
# Population 65+           -0.738466       0.342139               -0.286126
# Population Total          0.012781       0.629085                0.011781
# Population Urban         -0.592360       0.298178               -0.230867
# Tourism Inbound          -0.505635       0.611272               -0.264380
# Tourism Outbound         -0.453477       0.693706               -0.227990
#
#                         Energy Usage       GDP  Health Exp % GDP  \
# Birth Rate                 -0.283022 -0.414817         -0.238268
# CO2 Emissions               0.834030  0.731496          0.056862
# Days to Start Business     -0.154774 -0.207639         -0.225340
# Energy Usage                1.000000  0.801417          0.106609
# GDP                         0.801417  1.000000          0.236235
# Health Exp % GDP            0.106609  0.236235          1.000000
# Health Exp/Capita           0.337225  0.561051          0.429149
# Infant Mortality Rate      -0.224241 -0.387134         -0.206844
# Internet Usage              0.282114  0.490944          0.349519
# Lending Interest           -0.270503 -0.344059         -0.057009
# Life Expectancy Female      0.256495  0.415354          0.221774
# Life Expectancy Male        0.250669  0.426889          0.232064
# Mobile Phone Usage          0.195398  0.408253          0.198396
# Population 0-14            -0.341386 -0.505771         -0.297384
# Population 15-64            0.292995  0.417307          0.095832
# Population 65+              0.321727  0.501678          0.504073
# Population Total            0.706726  0.611984         -0.024224
# Population Urban            0.248088  0.414243          0.191847
# Tourism Inbound             0.651132  0.849741          0.302062
# Tourism Outbound            0.739654  0.931593          0.257110
#
#                         Health Exp/Capita  Infant Mortality Rate  \
# Birth Rate                      -0.586558               0.870159
# CO2 Emissions                    0.319254              -0.299015
# Days to Start Business          -0.305008               0.260893
# Energy Usage                     0.337225              -0.224241
# GDP                              0.561051              -0.387134
# Health Exp % GDP                 0.429149              -0.206844
# Health Exp/Capita                1.000000              -0.611669
# Infant Mortality Rate           -0.611669               1.000000
# Internet Usage                   0.768254              -0.615956
# Lending Interest                -0.489177               0.443005
# Life Expectancy Female           0.593077              -0.924283
# Life Expectancy Male             0.622326              -0.901555
# Mobile Phone Usage               0.583103              -0.571014
# Population 0-14                 -0.664706               0.814703
# Population 15-64                 0.540245              -0.797798
# Population 65+                   0.662062              -0.620503
# Population Total                 0.004744               0.058261
# Population Urban                 0.573658              -0.600789
# Tourism Inbound                  0.599589              -0.465210
# Tourism Outbound                 0.613099              -0.428932
#
#                         Internet Usage  Lending Interest  \
# Birth Rate                   -0.624617          0.423805
# CO2 Emissions                 0.188934         -0.246069
# Days to Start Business       -0.388139          0.209823
# Energy Usage                  0.282114         -0.270503
# GDP                           0.490944         -0.344059
# Health Exp % GDP              0.349519         -0.057009
# Health Exp/Capita             0.768254         -0.489177
# Infant Mortality Rate        -0.615956          0.443005
# Internet Usage                1.000000         -0.465822
# Lending Interest             -0.465822          1.000000
# Life Expectancy Female        0.639727         -0.448856
# Life Expectancy Male          0.659313         -0.479795
# Mobile Phone Usage            0.744721         -0.414366
# Population 0-14              -0.675302          0.441964
# Population 15-64              0.586666         -0.423364
# Population 65+                0.615580         -0.349192
# Population Total             -0.030459         -0.038709
# Population Urban              0.531437         -0.321967
# Tourism Inbound               0.550953         -0.420472
# Tourism Outbound              0.533144         -0.393515
#
#                         Life Expectancy Female  Life Expectancy Male  \
# Birth Rate                           -0.865210             -0.822416
# CO2 Emissions                         0.312254              0.295870
# Days to Start Business               -0.301963             -0.312340
# Energy Usage                          0.256495              0.250669
# GDP                                   0.415354              0.426889
# Health Exp % GDP                      0.221774              0.232064
# Health Exp/Capita                     0.593077              0.622326
# Infant Mortality Rate                -0.924283             -0.901555
# Internet Usage                        0.639727              0.659313
# Lending Interest                     -0.448856             -0.479795
# Life Expectancy Female                1.000000              0.976817
# Life Expectancy Male                  0.976817              1.000000
# Mobile Phone Usage                    0.549469              0.549407
# Population 0-14                      -0.811519             -0.767759
# Population 15-64                      0.779921              0.748423
# Population 65+                        0.638452              0.588590
# Population Total                     -0.033873             -0.043630
# Population Urban                      0.620423              0.618770
# Tourism Inbound                       0.493586              0.504987
# Tourism Outbound                      0.445836              0.463022
#
#                         Mobile Phone Usage  Population 0-14  Population 15-64  \
# Birth Rate                       -0.538916         0.941822         -0.908345
# CO2 Emissions                     0.142886        -0.396798          0.366395
# Days to Start Business           -0.317268         0.309020         -0.265334
# Energy Usage                      0.195398        -0.341386          0.292995
# GDP                               0.408253        -0.505771          0.417307
# Health Exp % GDP                  0.198396        -0.297384          0.095832
# Health Exp/Capita                 0.583103        -0.664706          0.540245
# Infant Mortality Rate            -0.571014         0.814703         -0.797798
# Internet Usage                    0.744721        -0.675302          0.586666
# Lending Interest                 -0.414366         0.441964         -0.423364
# Life Expectancy Female            0.549469        -0.811519          0.779921
# Life Expectancy Male              0.549407        -0.767759          0.748423
# Mobile Phone Usage                1.000000        -0.606302          0.576564
# Population 0-14                  -0.606302         1.000000         -0.925740
# Population 15-64                  0.576564        -0.925740          1.000000
# Population 65+                    0.485581        -0.841754          0.575797
# Population Total                 -0.056029        -0.037059          0.000278
# Population Urban                  0.461193        -0.603919          0.591404
# Tourism Inbound                   0.459792        -0.587283          0.478729
# Tourism Outbound                  0.428602        -0.542975          0.452036
#
#                         Population 65+  Population Total  Population Urban  \
# Birth Rate                   -0.738466          0.012781         -0.592360
# CO2 Emissions                 0.342139          0.629085          0.298178
# Days to Start Business       -0.286126          0.011781         -0.230867
# Energy Usage                  0.321727          0.706726          0.248088
# GDP                           0.501678          0.611984          0.414243
# Health Exp % GDP              0.504073         -0.024224          0.191847
# Health Exp/Capita             0.662062          0.004744          0.573658
# Infant Mortality Rate        -0.620503          0.058261         -0.600789
# Internet Usage                0.615580         -0.030459          0.531437
# Lending Interest             -0.349192         -0.038709         -0.321967
# Life Expectancy Female        0.638452         -0.033873          0.620423
# Life Expectancy Male          0.588590         -0.043630          0.618770
# Mobile Phone Usage            0.485581         -0.056029          0.461193
# Population 0-14              -0.841754         -0.037059         -0.603919
# Population 15-64              0.575797          0.000278          0.591404
# Population 65+                1.000000          0.086322          0.455564
# Population Total              0.086322          1.000000         -0.051197
# Population Urban              0.455564         -0.051197          1.000000
# Tourism Inbound               0.590368          0.465745          0.438128
# Tourism Outbound              0.532794          0.514969          0.460738
#
#                         Tourism Inbound  Tourism Outbound
# Birth Rate                    -0.505635         -0.453477
# CO2 Emissions                  0.611272          0.693706
# Days to Start Business        -0.264380         -0.227990
# Energy Usage                   0.651132          0.739654
# GDP                            0.849741          0.931593
# Health Exp % GDP               0.302062          0.257110
# Health Exp/Capita              0.599589          0.613099
# Infant Mortality Rate         -0.465210         -0.428932
# Internet Usage                 0.550953          0.533144
# Lending Interest              -0.420472         -0.393515
# Life Expectancy Female         0.493586          0.445836
# Life Expectancy Male           0.504987          0.463022
# Mobile Phone Usage             0.459792          0.428602
# Population 0-14               -0.587283         -0.542975
# Population 15-64               0.478729          0.452036
# Population 65+                 0.590368          0.532794
# Population Total               0.465745          0.514969
# Population Urban               0.438128          0.460738
# Tourism Inbound                1.000000          0.888137
# Tourism Outbound               0.888137          1.000000

# %%
from sklearn.preprocessing import StandardScaler
sd = StandardScaler()
df_scaled = sd.fit_transform(df2) #Scaling the dataset using StandardScaler
df_scaled = pd.DataFrame(df_scaled, columns=df2.columns) #Converting Into DataFrame After Scaling
df_scaled.head()
# Out:
#    Birth Rate  CO2 Emissions  Days to Start Business  Energy Usage       GDP  \
# 0   -0.233864       1.659733               -0.151075      0.590969 -0.060055
# 1    2.469335      -0.486142               -0.151075     -0.729010 -0.620533
# 2    1.838589      -0.703087               -0.151075     -1.102414 -0.703641
# 3    0.396882      -0.630298               -0.151075     -1.112365 -0.661547
# 4    2.108909      -0.718855               -0.151075     -0.266046 -0.700549
#
#    Health Exp % GDP  Health Exp/Capita  Infant Mortality Rate  Internet Usage  \
# 0         -1.266291          -0.746454               0.092012       -0.908914
# 1         -1.311467          -0.831569               2.697530       -0.908914
# 2         -0.904880          -0.847248               2.077168       -0.908914
# 3         -0.724175          -0.540387               0.800996       -0.908914
# 4         -0.543469          -0.853967               2.289864       -0.908914
#
#    Lending Interest  Life Expectancy Female  Life Expectancy Male  \
# 0         -0.531416               -0.034833              0.043864
# 1          2.067567               -2.334437             -2.472735
# 2         -0.120510               -1.376268             -1.487979
# 3          0.598576               -1.855353             -1.925648
# 4         -0.120510               -1.855353             -1.925648
#
#    Mobile Phone Usage  Population 0-14  Population 15-64  Population 65+  \
# 0           -1.253652         0.384182         -0.089411       -0.684821
# 1           -1.253652         1.696192         -1.886942       -0.978160
# 2           -1.253652         1.480788         -1.617312       -0.894348
# 3           -1.034604         0.785618         -0.568753       -0.894348
# 4           -1.253652         1.617863         -1.797065       -0.915301
#
#    Population Total  Population Urban  Tourism Inbound  Tourism Outbound
# 0          1.090800          0.147449        -0.754222         -0.670804
# 1          0.021270         -0.976530        -0.783976         -0.702383
# 2         -0.397993         -0.735385        -0.765161         -0.766886
# 3         -0.710175         -0.126393        -0.699527         -0.660053
# 4         -0.117991         -1.573260        -0.788789         -0.780324

# %%
plt.figure(figsize = (40,10))
sns.boxplot(df_scaled)
# Out:
# <Axes: >

# %%
from sklearn.decomposition import PCA #import PCA
pca = PCA(n_components=20)
pcomp = pca.fit_transform(df_scaled) #fit_transform df_scaled using PCA

# %%
col = []
for i in range(1,21):
    col.append('PC'+str(i))  #Create Column Names For PCA Components
    
df_pca = pd.DataFrame(pcomp, columns=col) #Convert PCA Components Into DataFrame With Column Names
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  0.841152  1.334324 -2.152344 -0.194966 -0.938837 -0.600163  0.944951
# 1  5.981137  1.682839  1.134982 -0.453750 -0.440756  1.277861 -0.498669
# 2  4.660103  0.477959  0.718807 -1.078308 -0.029501 -0.304612  0.524939
# 3  3.518131 -0.218426  0.208838 -0.248240 -0.185839  0.435861  0.012226
# 4  5.117223  1.299910  1.210109 -1.025742 -0.103486 -0.799969  0.055401
#
#         PC8       PC9      PC10      PC11      PC12      PC13      PC14  \
# 0 -0.424237 -0.770399  0.210256  0.482794  0.127501 -0.120697  0.441000
# 1 -0.918421  0.646630  0.845597  0.368611  0.240694  0.038099  0.330921
# 2 -0.662705  0.646900  0.135902  0.273072  0.269140  0.154533  0.255845
# 3 -1.443681  0.548172  0.074780 -0.189265 -0.393758 -0.338644  0.100333
# 4 -0.589656  0.194619  0.330264  0.116085  0.105203  0.291692 -0.068631
#
#        PC15      PC16      PC17      PC18      PC19      PC20
# 0 -0.329381 -0.004627 -0.289562 -0.345691 -0.106912  0.006391
# 1 -0.155759  0.300682 -0.044053  0.253934  0.126509 -0.007114
# 2 -0.379895  0.404178 -0.088869  0.065047  0.186715 -0.002712
# 3 -0.099508 -0.786474 -0.258364 -0.379149 -0.045634 -0.000827
# 4 -0.002740  0.277207 -0.024231  0.183246  0.135336  0.005580

# %%
exl_var = pca.explained_variance_ratio_  #Calculate Explained Variance Ratio For Each PCA Component
np.round(exl_var, 3)
# Out:
# array([0.506, 0.159, 0.068, 0.049, 0.04 , 0.032, 0.03 , 0.023, 0.018,
#        0.016, 0.014, 0.012, 0.009, 0.007, 0.005, 0.005, 0.003, 0.002,
#        0.001, 0.   ])

# %%
np.cumsum(exl_var).round(3)  #cululative sum of explained variance ratio
# Out:
# array([0.506, 0.665, 0.734, 0.783, 0.823, 0.855, 0.885, 0.908, 0.926,
#        0.942, 0.956, 0.968, 0.977, 0.984, 0.99 , 0.994, 0.997, 0.999,
#        1.   , 1.   ])

# %%
final_df = df_pca.iloc[:,:11] #Selecting the first 11 PCA components which explain around 95% of the variance in the data
final_df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  0.841152  1.334324 -2.152344 -0.194966 -0.938837 -0.600163  0.944951
# 1  5.981137  1.682839  1.134982 -0.453750 -0.440756  1.277861 -0.498669
# 2  4.660103  0.477959  0.718807 -1.078308 -0.029501 -0.304612  0.524939
# 3  3.518131 -0.218426  0.208838 -0.248240 -0.185839  0.435861  0.012226
# 4  5.117223  1.299910  1.210109 -1.025742 -0.103486 -0.799969  0.055401
#
#         PC8       PC9      PC10      PC11
# 0 -0.424237 -0.770399  0.210256  0.482794
# 1 -0.918421  0.646630  0.845597  0.368611
# 2 -0.662705  0.646900  0.135902  0.273072
# 3 -1.443681  0.548172  0.074780 -0.189265
# 4 -0.589656  0.194619  0.330264  0.116085

# %%
plt.figure(figsize = (6,6))
sns.heatmap(final_df.corr()>0.7, annot = True, cmap = 'coolwarm') #Plot Heatmap To Identify Correlation Between PCA Components
plt.show()

# %%
from sklearn.manifold import TSNE                                       #importting TSNE
tsne = TSNE(n_components= 2, perplexity=40)                             
tsne_comp = tsne.fit_transform(final_df)                                #fit_transform final_df using TSNE
tsne_df = pd.DataFrame(tsne_comp, columns=['TSNE1', 'TSNE2'])           #Convert TSNE Components Into DataFrame
tsne_df.head()
# Out:
#        TSNE1      TSNE2
# 0  -0.697508  27.519169
# 1  48.920822  25.281994
# 2  39.115788  13.782447
# 3  34.911358   9.388482
# 4  49.789021  13.003651

# %%
plt.figure(figsize=(8,6))
plt.scatter(data= tsne_df, x='TSNE1', y='TSNE2' ) #Plotting t-SNE Visualization
plt.title("t-SNE Visualization")
plt.show()

# %% [markdown]
# # Model Building

# %%
from sklearn.cluster import KMeans #importing KMeans

inertia = []
for k in range(1,11):
    kmeans = KMeans(n_clusters = k, random_state = 42)
    kmeans.fit(final_df)
    inertia.append(kmeans.inertia_) #Calculate Inertia For Each Value Of K

plt.figure(figsize = (8,5))
plt.plot(range(1,11), inertia, marker = "o")  #Plotting Elbow Method 
plt.title("Elbow Method For Otimal K")
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia")   
plt.show()

# %% [markdown]
# # KMeans

# %%
km = KMeans(n_clusters = 3, random_state = 42)
km.fit(final_df) #fit final_df using KMeans
pred_km = km.predict(final_df) #Predict Cluster Labels

# %%
from sklearn.metrics import silhouette_score 
silhouette_avg = silhouette_score(final_df, km.labels_) #Calculate Silhouette Score For KMeans Clustering
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.30290388362430365

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x = final_df['PC1'], y = final_df['PC2'], hue=pred_km, palette='Set1') #Plotting Clusters Based On First Two PCA Components
plt.title("KMeans Clusters Based on PCA Components")
# Out:
# Text(0.5, 1.0, 'KMeans Clusters Based on PCA Components')

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN

eps_values = [0.3,1.5, 2, 2.5, 3, 3.5, 4, 4.5]
min_samples_values = [3, 5, 10, 15]

for eps in eps_values:
    for min_samples in min_samples_values:
        db = DBSCAN(eps=eps, min_samples=min_samples)
        labels = db.fit_predict(final_df)
        n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
        sil_score = -1
        if n_clusters > 1:
            sil_score = silhouette_score(final_df, labels)
        print(f"EPS: {eps}, MinPts: {min_samples}, Clusters: {n_clusters}, Silhouette Score: {sil_score:.3f}")
# Out:
# EPS: 0.3, MinPts: 3, Clusters: 120, Silhouette Score: -0.388
# EPS: 0.3, MinPts: 5, Clusters: 18, Silhouette Score: -0.399
# EPS: 0.3, MinPts: 10, Clusters: 4, Silhouette Score: -0.268
# EPS: 0.3, MinPts: 15, Clusters: 1, Silhouette Score: -1.000
# EPS: 1.5, MinPts: 3, Clusters: 77, Silhouette Score: -0.176
# EPS: 1.5, MinPts: 5, Clusters: 53, Silhouette Score: -0.190
# EPS: 1.5, MinPts: 10, Clusters: 18, Silhouette Score: -0.230
# EPS: 1.5, MinPts: 15, Clusters: 5, Silhouette Score: -0.093
# EPS: 2, MinPts: 3, Clusters: 9, Silhouette Score: -0.227
# EPS: 2, MinPts: 5, Clusters: 9, Silhouette Score: -0.216
# EPS: 2, MinPts: 10, Clusters: 7, Silhouette Score: -0.153
# EPS: 2, MinPts: 15, Clusters: 1, Silhouette Score: -1.000
# EPS: 2.5, MinPts: 3, Clusters: 2, Silhouette Score: 0.184
# EPS: 2.5, MinPts: 5, Clusters: 2, Silhouette Score: 0.004
# EPS: 2.5, MinPts: 10, Clusters: 3, Silhouette Score: 0.026
# EPS: 2.5, MinPts: 15, Clusters: 1, Silhouette Score: -1.000
# EPS: 3, MinPts: 3, Clusters: 2, Silhouette Score: 0.184
# EPS: 3, MinPts: 5, Clusters: 2, Silhouette Score: 0.184
# EPS: 3, MinPts: 10, Clusters: 2, Silhouette Score: 0.184
# EPS: 3, MinPts: 15, Clusters: 1, Silhouette Score: -1.000
# EPS: 3.5, MinPts: 3, Clusters: 1, Silhouette Score: -1.000
# EPS: 3.5, MinPts: 5, Clusters: 1, Silhouette Score: -1.000
# EPS: 3.5, MinPts: 10, Clusters: 1, Silhouette Score: -1.000
# EPS: 3.5, MinPts: 15, Clusters: 1, Silhouette Score: -1.000
# EPS: 4, MinPts: 3, Clusters: 1, Silhouette Score: -1.000
# EPS: 4, MinPts: 5, Clusters: 1, Silhouette Score: -1.000
# EPS: 4, MinPts: 10, Clusters: 1, Silhouette Score: -1.000
# EPS: 4, MinPts: 15, Clusters: 1, Silhouette Score: -1.000
# EPS: 4.5, MinPts: 3, Clusters: 1, Silhouette Score: -1.000
# EPS: 4.5, MinPts: 5, Clusters: 1, Silhouette Score: -1.000
# EPS: 4.5, MinPts: 10, Clusters: 1, Silhouette Score: -1.000
# EPS: 4.5, MinPts: 15, Clusters: 1, Silhouette Score: -1.000

# %%
db = DBSCAN(eps=2.5, min_samples=3)
pred_db= db.fit_predict(final_df) #fit_predict final_df using DBSCAN

# %%
silhouette_avg = silhouette_score(final_df, pred_db) #Calculate Silhouette Score For DBScan Clustering
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.18373581844522924

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x = final_df['PC1'], y = final_df['PC2'], hue=pred_db, palette='Set1') #Plotting Clusters Based On First Two PCA Components
plt.title("KMeans Clusters Based on PCA Components")
# Out:
# Text(0.5, 1.0, 'KMeans Clusters Based on PCA Components')

# %% [markdown]
# # Hierarchical clustering / Agglomerative clustering

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score

linkages = ['ward','complete','average','single']

for linkage in linkages:
    for k in range(2,5):   # testing clusters from 2 to 4
        
        # ward only works with euclidean distance
        if linkage == 'ward':
            model = AgglomerativeClustering(n_clusters=k, linkage=linkage)
        else:
            model = AgglomerativeClustering(n_clusters=k, linkage=linkage, metric='euclidean')
        
        labels = model.fit_predict(final_df)
        score = silhouette_score(final_df, labels)
        
        print(f"Linkage: {linkage}, Clusters: {k}, Silhouette Score: {score:.3f}")
# Out:
# Linkage: ward, Clusters: 2, Silhouette Score: 0.273
# Linkage: ward, Clusters: 3, Silhouette Score: 0.270
# Linkage: ward, Clusters: 4, Silhouette Score: 0.282
# Linkage: complete, Clusters: 2, Silhouette Score: 0.287
# Linkage: complete, Clusters: 3, Silhouette Score: 0.253
# Linkage: complete, Clusters: 4, Silhouette Score: 0.283
# Linkage: average, Clusters: 2, Silhouette Score: 0.333
# Linkage: average, Clusters: 3, Silhouette Score: 0.270
# Linkage: average, Clusters: 4, Silhouette Score: 0.236
# Linkage: single, Clusters: 2, Silhouette Score: 0.184
# Linkage: single, Clusters: 3, Silhouette Score: 0.067
# Linkage: single, Clusters: 4, Silhouette Score: -0.044

# %%
agg = AgglomerativeClustering(n_clusters=2, linkage='average') #Create AgglomerativeClustering Model With Optimal Parameters
pred_agg = agg.fit_predict(final_df)

# %%
silhouette_avg = silhouette_score(final_df, pred_agg) #Calculate Silhouette Score For KMeans Clustering
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.3329578481422238

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x = final_df['PC1'], y = final_df['PC2'], hue=pred_agg, palette='Set1') #Plotting Clusters Based On First Two PCA Components
plt.title("KMeans Clusters Based on PCA Components")
# Out:
# Text(0.5, 1.0, 'KMeans Clusters Based on PCA Components')

# %% [markdown]
# # Gaussian Mixture Model (GMM)

# %%
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score

cov_types = ['full','tied','diag','spherical']

for cov in cov_types:
    for k in range(2,5):   # testing clusters from 2 to 4
        
        gmm = GaussianMixture(
            n_components=k,
            covariance_type=cov,
            random_state=42
        )
        
        labels = gmm.fit_predict(final_df)
        score = silhouette_score(final_df, labels)
        
        print(f"Covariance: {cov}, Clusters: {k}, Score: {score:.3f}")
# Out:
# Covariance: full, Clusters: 2, Score: 0.256
# Covariance: full, Clusters: 3, Score: 0.221
# Covariance: full, Clusters: 4, Score: 0.217
# Covariance: tied, Clusters: 2, Score: 0.280
# Covariance: tied, Clusters: 3, Score: 0.282
# Covariance: tied, Clusters: 4, Score: 0.199
# Covariance: diag, Clusters: 2, Score: 0.233
# Covariance: diag, Clusters: 3, Score: 0.194
# Covariance: diag, Clusters: 4, Score: 0.126
# Covariance: spherical, Clusters: 2, Score: 0.294
# Covariance: spherical, Clusters: 3, Score: 0.296
# Covariance: spherical, Clusters: 4, Score: 0.218

# %%
gmm = GaussianMixture(n_components=3, covariance_type='spherical', random_state=42)
pred_gmm = gmm.fit_predict(final_df)

# %%
silhouette_avg = silhouette_score(final_df, pred_gmm) #Calculate Silhouette Score For KMeans Clustering
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.2963140529666221

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x = final_df['PC1'], y = final_df['PC2'], hue=pred_gmm, palette='Set1') #Plotting Clusters Based On First Two PCA Components
plt.title("KMeans Clusters Based on PCA Components")
# Out:
# Text(0.5, 1.0, 'KMeans Clusters Based on PCA Components')
